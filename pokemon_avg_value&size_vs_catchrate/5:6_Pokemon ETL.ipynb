# %%
#dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pymysql
from sqlalchemy import create_engine

# %%
df = pd.read_csv("Pokemon_B.csv")
# plt.scatter()

w = 3
h = 4
d = 100
size = 5

plt.figure(figsize=(w, h), dpi=d)

df.plot(kind="scatter", x="Size_Score", y="Catch_Rate", s=size)


    
#plt.xlim()
#plt.xlim()


plt.title("Size Score v. Catchability")
plt.xlabel("Size Score (weight/height)")
plt.ylabel("Catch Score (Max 255)")
# Out:
# Text(0,0.5,'Catch Score (Max 255)')

# %%
#Load in csv catch_df = pd.read_csv("") catch_df.head()
select_columns = ["Pr_Male", "Size_Score"]
df[select_columns]
# Out:
#      Pr_Male  Size_Score
# 0      0.875    9.718310
# 1      0.875   13.131313
# 2      0.875   49.751244
# 3      0.875   13.934426
# 4      0.875   17.431193
# 5      0.875   53.235294
# 6      0.875   17.647059
# 7      0.875   22.727273
# 8      0.875   53.437500
# 9      0.500    9.666667
# 10     0.500   13.943662
# 11     0.500   29.357798
# 12     0.500   10.666667
# 13     0.500   16.393443
# 14     0.500   29.797980
# 15     0.500    6.000000
# 16     0.500   27.522936
# 17     0.500   26.333333
# 18     0.500   11.666667
# 19     0.500   26.056338
# 20     0.500    6.666667
# 21     0.500   31.932773
# 22     0.500    3.432836
# 23     0.500   18.518519
# 24     0.500   14.634146
# 25     0.500   37.974684
# 26     0.500   19.672131
# 27     0.500   29.797980
# 28     0.000   17.073171
# 29     0.000   25.316456
# ..       ...         ...
# 691    0.500   16.274510
# 692    0.500   27.153846
# 693    0.500   11.764706
# 694    0.500   21.212121
# 695    0.875   32.911392
# ...

# %%
w = 30
h = 40
d = 150
size = 500

plt.figure(figsize=(w, h), dpi=150)

df = pd.read_csv("Pokemon_B.csv")
# plt.scatter()
df.plot(kind="scatter", x="Pr_Male", y="Catch_Rate")
